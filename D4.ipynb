# %% [markdown]
# <a href="https://colab.research.google.com/github/NoorHadiya/.ipynbnotes/blob/main/D4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#PANDAS=USED TO CREATE DATAFRAMES AND SERIES
#DATAFRAME=TABLED DATA
#SERIES=COLUMNS

# %%
mydataset={'cars': ['BMW', 'MERC', 'SUPRA'], 'passings' :[3,7,2]}
mydataset
# Out:
# {'cars': ['BMW', 'MERC', 'SUPRA'], 'passings': [3, 7, 2]}

# %%
type(mydataset)
# Out:
# dict

# %%
import pandas as pd
df= pd.DataFrame(mydataset)
df
# Out:
#     cars  passings
# 0    BMW         3
# 1   MERC         7
# 2  SUPRA         2

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
a = [1,2,3,4]
myvar = pd.Series(a)
myvar
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
#CHANGING INDEX
a=[1,2,3,4]
myvar1 = pd.Series(a, index = ['w', 'x', 'y', 'z'])
myvar1
# Out:
# w    1
# x    2
# y    3
# z    4
# dtype: int64

# %%
sports1 = pd.Series([1,2,3,4], index = ['cricket', 'football', 'hockey', 'golf'])
sports1
# Out:
# cricket     1
# football    2
# hockey      3
# golf        4
# dtype: int64

# %%
sports2 = pd.Series([1,2,3,4] , index = ['cricket', 'basketball', 'baseball', 'golf'])
sports2
# Out:
# cricket       1
# basketball    2
# baseball      3
# golf          4
# dtype: int64

# %%
s = sports1+sports2
s
# Out:
# baseball      NaN
# basketball    NaN
# cricket       2.0
# football      NaN
# golf          8.0
# hockey        NaN
# dtype: float64

# %%
#NAN-NOT A NUMBER
#OR NULL VALUE/MISSING VALUE
#IF NAN IS PRESENT INT IS CONVERTED TO FLOAT

# %%
#DROPPING ALL THE NULL VALUES
s.dropna()
# Out:
# cricket    2.0
# golf       8.0
# dtype: float64

# %%
#REPLACING NAN WITH VALUES
e = s.fillna(value =11)
e
# Out:
# baseball      11.0
# basketball    11.0
# cricket        2.0
# football      11.0
# golf           8.0
# hockey        11.0
# dtype: float64

# %%
#EXPLORATORY DATA ANALYSIS (EDA) - PRE MACHINE LEARNING
#WE FIND DIFF INSIGHTS AND COME TO DIFF CONCLUSIONS AND EXPLORE OUR DATA
#DATASET - RAW UNPROCESSED DATA IN FORM OF ROWS AND COLUMNS

# %%
#DATASET - https://storage.googleapis.com/kagglesdsdata/datasets/9590/13660/fruit_data_with_colors.txt?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20230105%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20230105T050539Z&X-Goog-Expires=259200&X-Goog-SignedHeaders=host&X-Goog-Signature=...
#STEP 1. TAKE DATA AND CREATE DATAFRAME
import pandas as pd
df = pd.read_csv('https://storage.googleapis.com/kagglesdsdata/datasets/9590/13660/fruit_data_with_colors.txt?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20230105%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20230105T050539Z&X-Goog-Expires=259200&X-Goog-SignedHeaders=host&X-Goog-Signature=...', sep ='\t')
df
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-3-eee17868c0ab> in <module>
#       2 #STEP 1. TAKE DATA AND CREATE DATAFRAME
#       3 import pandas as pd
# ----> 4 df = pd.read_csv('https://storage.googleapis.com/kagglesdsdata/datasets/9590/13660/fruit_data_with_colors.txt?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20230105%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20230105T050539Z&X-Goog-Expires=259200&X-Goog-SignedHeaders=host&X-Goog-Signature=...', sep ='\t')
#       5 df
#
# /usr/local/lib/python3.8/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
df.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-633337079cd0> in <module>
# ----> 1 df.shape
#
# NameError: name 'df' is not defined

# %%
import pandas as pd
df = pd.read_csv('https://storage.googleapis.com/kagglesdsdata/datasets/9590/13660/fruit_data_with_colors.txt?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20230110%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20230110T183858Z&X-Goog-Expires=259200&X-Goog-SignedHeaders=host&X-Goog-Signature=...', sep='\t')
df
# Out:
#     fruit_label fruit_name     fruit_subtype  mass  width  height  color_score
# 0             1      apple      granny_smith   192    8.4     7.3         0.55
# 1             1      apple      granny_smith   180    8.0     6.8         0.59
# 2             1      apple      granny_smith   176    7.4     7.2         0.60
# 3             2   mandarin          mandarin    86    6.2     4.7         0.80
# 4             2   mandarin          mandarin    84    6.0     4.6         0.79
# 5             2   mandarin          mandarin    80    5.8     4.3         0.77
# 6             2   mandarin          mandarin    80    5.9     4.3         0.81
# 7             2   mandarin          mandarin    76    5.8     4.0         0.81
# 8             1      apple          braeburn   178    7.1     7.8         0.92
# 9             1      apple          braeburn   172    7.4     7.0         0.89
# 10            1      apple          braeburn   166    6.9     7.3         0.93
# ...

# %%
df = pd.read_csv('/content/fruit_data_with_colors.txt', sep = '\t')
df
# Out:
#     fruit_label fruit_name     fruit_subtype  mass  width  height  color_score
# 0             1      apple      granny_smith   192    8.4     7.3         0.55
# 1             1      apple      granny_smith   180    8.0     6.8         0.59
# 2             1      apple      granny_smith   176    7.4     7.2         0.60
# 3             2   mandarin          mandarin    86    6.2     4.7         0.80
# 4             2   mandarin          mandarin    84    6.0     4.6         0.79
# 5             2   mandarin          mandarin    80    5.8     4.3         0.77
# 6             2   mandarin          mandarin    80    5.9     4.3         0.81
# 7             2   mandarin          mandarin    76    5.8     4.0         0.81
# 8             1      apple          braeburn   178    7.1     7.8         0.92
# 9             1      apple          braeburn   172    7.4     7.0         0.89
# 10            1      apple          braeburn   166    6.9     7.3         0.93
# ...

# %%
df.shape
# Out:
# (59, 7)

# %%
df.size #total no of elements
# Out:
# 413

# %%
df.info() #info about the dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59 entries, 0 to 58
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   fruit_label    59 non-null     int64
#  1   fruit_name     59 non-null     object
#  2   fruit_subtype  59 non-null     object
#  3   mass           59 non-null     int64
#  4   width          59 non-null     float64
#  5   height         59 non-null     float64
#  6   color_score    59 non-null     float64
# dtypes: float64(3), int64(2), object(2)
# memory usage: 3.4+ KB

# %%
#SLICING
#SLICE FROM 25 TO 43.
#var[inclusive:exclusive]
import pandas as pd
df = pd.read_csv('/content/fruit_data_with_colors.txt', sep = '\t')
df[25:44]
df
# Out:
#     fruit_label fruit_name     fruit_subtype  mass  width  height  color_score
# 0             1      apple      granny_smith   192    8.4     7.3         0.55
# 1             1      apple      granny_smith   180    8.0     6.8         0.59
# 2             1      apple      granny_smith   176    7.4     7.2         0.60
# 3             2   mandarin          mandarin    86    6.2     4.7         0.80
# 4             2   mandarin          mandarin    84    6.0     4.6         0.79
# 5             2   mandarin          mandarin    80    5.8     4.3         0.77
# 6             2   mandarin          mandarin    80    5.9     4.3         0.81
# 7             2   mandarin          mandarin    76    5.8     4.0         0.81
# 8             1      apple          braeburn   178    7.1     7.8         0.92
# 9             1      apple          braeburn   172    7.4     7.0         0.89
# 10            1      apple          braeburn   166    6.9     7.3         0.93
# ...

# %%
df.iloc[25:44,0:2]
# Out:
#     fruit_label fruit_name
# 25            3     orange
# 26            3     orange
# 27            3     orange
# 28            3     orange
# 29            3     orange
# 30            3     orange
# 31            3     orange
# 32            3     orange
# 33            3     orange
# 34            3     orange
# 35            3     orange
# 36            3     orange
# 37            3     orange
# 38            3     orange
# 39            3     orange
# 40            3     orange
# 41            3     orange
# 42            3     orange
# 43            4      lemon

# %%
df.fruit_name.nunique()
# Out:
# 4

# %%
df.fruit_label.nunique()
# Out:
# 4

# %%
df['fruit_name'].nunique()
# Out:
# 4

# %%
df.fruit_label.unique()
# Out:
# array([1, 2, 3, 4])

# %%
fname = df.fruit_name.unique()
fname
# Out:
# array(['apple', 'mandarin', 'orange', 'lemon'], dtype=object)

# %%
#19-APPLES
#19-LEMONS
#5-MANDRINS
#16-ORANGES
fsize = df.groupby('fruit_name', sort = False).size()#HERE .GROUPBY SORTS IN ALPHABETICAL ORDER
fsize
# Out:
# fruit_name
# apple       19
# mandarin     5
# orange      19
# lemon       16
# dtype: int64

# %%
#VISIUALISATION
import matplotlib.pyplot as plt
plt.bar(fname, fsize, color=['gold', 'orange', 'lime', 'red'])
# Out:
# <BarContainer object of 4 artists>
